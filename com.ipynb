# %%
import numpy as np
import matplotlib.pyplot as plt
lags = np.arange(1,97)
vals = np.load("resultfile/results/shap/lag_imp_chl.npy")
plt.plot(lags, vals)
plt.xlabel('Lag (Time Step)')
plt.ylabel('SHAP Importance')
plt.title('Temporal Importance for Chlorophyll Prediction')
plt.tight_layout()
plt.savefig('shap_lag_importance.png', dpi=300)

# %%
import numpy as np
vals=np.load('resultfile/results/shap/lag_imp_chl.npy')

# %%
print(vals)
# Out:
# [2.50486661e-04 9.24182174e-05 1.10771817e-04 1.52014615e-04
#  1.62790661e-04 1.49622344e-04 2.26252793e-04 3.42727431e-04
#  3.44005403e-04 2.77581566e-04 1.41863405e-04 2.07496460e-04
#  2.42564388e-04 1.04085192e-04 1.88634323e-04 1.30099183e-04
#  1.00822148e-04 1.50697028e-04 1.88835223e-04 6.14996458e-05
#  8.96347268e-05 1.09769961e-04 1.93959412e-04 1.45133032e-04
#  1.20253706e-04 8.42687994e-05 2.73409246e-04 1.15888908e-04
#  8.34504747e-05 7.48578278e-05 6.75979916e-05 1.62775483e-04
#  1.07695271e-04 1.38307141e-04 1.56616434e-04 1.06726061e-04
#  1.23534568e-04 9.10877818e-05 3.87904482e-05 8.81063879e-05
#  4.68703908e-05 4.68193610e-05 5.41443346e-05 5.69338649e-05
#  5.63898738e-05 1.49661170e-04 1.18484237e-04 2.13584207e-04
#  4.04021181e-04 3.04132200e-04 2.66387569e-04 3.10407022e-04
#  2.30798662e-04 2.19961498e-04 1.02075654e-04 1.83429882e-04
#  9.44938268e-05 2.21468765e-04 1.40921354e-04 1.61645202e-04
# ...

# %%
x=[]
x=vals
print('Temporal lag importance at each time step-')
print(x)

print(len(x))
# Out:
# Temporal lag importance at each time step-
# [2.50486661e-04 9.24182174e-05 1.10771817e-04 1.52014615e-04
#  1.62790661e-04 1.49622344e-04 2.26252793e-04 3.42727431e-04
#  3.44005403e-04 2.77581566e-04 1.41863405e-04 2.07496460e-04
#  2.42564388e-04 1.04085192e-04 1.88634323e-04 1.30099183e-04
#  1.00822148e-04 1.50697028e-04 1.88835223e-04 6.14996458e-05
#  8.96347268e-05 1.09769961e-04 1.93959412e-04 1.45133032e-04
#  1.20253706e-04 8.42687994e-05 2.73409246e-04 1.15888908e-04
#  8.34504747e-05 7.48578278e-05 6.75979916e-05 1.62775483e-04
#  1.07695271e-04 1.38307141e-04 1.56616434e-04 1.06726061e-04
#  1.23534568e-04 9.10877818e-05 3.87904482e-05 8.81063879e-05
#  4.68703908e-05 4.68193610e-05 5.41443346e-05 5.69338649e-05
#  5.63898738e-05 1.49661170e-04 1.18484237e-04 2.13584207e-04
#  4.04021181e-04 3.04132200e-04 2.66387569e-04 3.10407022e-04
#  2.30798662e-04 2.19961498e-04 1.02075654e-04 1.83429882e-04
#  9.44938268e-05 2.21468765e-04 1.40921354e-04 1.61645202e-04
# ...

# %%
feat=np.load('resultfile/results/shap/feat_imp_chl.npy')
print(feat)
# Out:
# [5.85353980e-05 5.80514594e-05 5.56420594e-05 1.15893051e-04
#  7.36932249e-05 4.22687613e-05 2.02441914e-03 2.54226203e-05]

# %%
names=['F1','F2', 'F3', 'F4', 'F5', 'F6', 'F7', 'F8']
plt.bar(names,feat)
plt.xlabel('Names of Features')
plt.ylabel('Feature Importance')
plt.title('Feature Importance for Chlorophyll')
plt.tight_layout()
plt.savefig('feat_importance', dpi=300)

fig
plt.figlegend(('F1-Conductivity (S/m), F2-Density (kg/m3), F3-Practical Salinity (psu), F4-Pressure (decibar), F5-Temperature (C), F6-Turbidity (NTU), F7-Chlorophyll (ug/l), F8-Oxygen Concentration Corrected (ml/l)'))
